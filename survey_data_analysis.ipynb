# %%
<h2>Girls Power Initiative (GPI)</h2>
<h3>INTEGRATED PROJECT BASELINE DATA ANALYSIS</h3>
# Out:
#   Cell In[21], line 1
#     <h3>INTEGRATED PROJECT BASELINE DATA ANALYSIS</h3>
#     ^
# SyntaxError: invalid syntax

# %%
<p>Girls Power Initiative (GPI) Integrated Action to reduce Human Trafficking Project being implemented by the Embassy 0f Switzerland in Nigeria.</p>
<p>GPI conducted the survey about trafficking in persons and other related topics in Edo State to serve as a baseline for the project.</p>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
survey_response = pd.read_csv('survey.csv')
survey_response.head()
# Out:
#       Sex              LGA Community How old were you at your last birthday?  \
# 0    Male  Ovia North East     Oluku                                   18-24
# 1    Male  Ovia North East     Oluku                                   25-30
# 2    Male  Ovia North East     Oluku                                   25-30
# 3  Female  Ovia North East     Oluku                                   18-24
# 4  Female  Ovia North East     Oluku                            31 and Above
#
#   What religion do you practice? Ethnic group: What is your marital status?\t  \
# 0                   Christianity        Others                         Single
# 1                          Islam         Hausa                        Married
# 2                   Christianity           Edo                     Cohabiting
# 3                   Christianity           Edo                         Single
# 4                   Christianity           Edo                        Married
#
# ...

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # Sample DataFrame
# survey_response = pd.read_csv('survey.csv')

# # Count the number of males and females
# gender_counts = survey_response['Sex'].value_counts()

# # Create a bar plot
# bars = plt.bar(gender_counts.index, gender_counts.values, color=['blue', 'pink'])

# # Add labels and title
# plt.xlabel('Gender')
# plt.ylabel('Number of Respondents')
# plt.title('Number of Male and Female Respondents')

# # Add data labels to the bars
# for bar in bars:
#     yval = bar.get_height()
#     plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom', color='black')

# # Show the graph
# plt.show()

# Count the number of males and females
gender_counts = survey_response['Sex'].value_counts()

# Labels and colors for each category
labels = gender_counts.index
colors = ['blue', 'pink']

# Create a pie chart
plt.figure(figsize=(12, 6))
plt.pie(gender_counts, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)

# Equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')

# Title
plt.title('Gender Distribution')

# Show the pie chart
plt.show()

# %%
Number of respondents by Local Government Areas

# %%
# Count responses by Local Government Areas 
LGA_counts = survey_response['LGA'].value_counts()

# Create a bar plot
bars = plt.bar(LGA_counts.index, LGA_counts.values, color=['Green', 'Yellow'])

# Add labels and title
plt.xlabel('Local Government Areas')
plt.ylabel('Number of Respondents')
plt.title('Number of Respondents by Local Government Areas')

# Add data labels to the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom', color='black')

# Show the graph
plt.show()

# %%
# Count the number of respondents for each religion
religion_counts = survey_response['What religion do you practice?'].value_counts()

# Labels and colors for each category
labels = religion_counts.index
colors = ['blue', 'green', 'orange', 'gray']

# Create a bar chart
plt.figure(figsize=(12, 6))
bars = plt.bar(labels, religion_counts, color=colors)

# Add data labels to the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, yval, ha='center', va='bottom', color='black')

# Add labels and title
plt.xlabel('Religion')
plt.ylabel('Number of Respondents')
plt.title('Religion Distribution')

# Show the bar chart
plt.show()
